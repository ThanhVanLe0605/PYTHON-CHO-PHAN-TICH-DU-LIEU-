# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhVanLe0605/PYTHON-CHO-PHAN-TICH-DU-LIEU-/blob/main/Ch%C6%B0%C6%A1ng_07_Enum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 7.1. Khởi tạo

# %%
# !pip install enum34

# %%
from enum import Enum

class Color(Enum):
  red = 1
  green = 2
  blue = 3

print(Color.red)
print(Color(1))
print(Color['red'])
# Out:
# Color.red
# Color.red
# Color.red

# %% [markdown]
# # 7.2. Khả năng lập

# %%
class Color(Enum):
  red = 1
  green = 2
  blue = 3
[c for c in Color]
# Out:
# [<Color.red: 1>, <Color.green: 2>, <Color.blue: 3>]

# %% [markdown]
# # BÀI TẬP CHƯƠNG 07

# %% [markdown]
# ##  Cấp độ 1 – Cơ bản (Khai báo, truy cập, duyệt)

# %% [markdown]
# ### Bài 1 – Phân loại sản phẩm

# %% [markdown]
# Công ty bán hàng có 3 loại sản phẩm: ĐIỆN_TỬ, THỜI_TRANG, GIA_DỤNG.
#
# **Yêu cầu:**
#
# * Khai báo enum ProductCategory với các giá trị tương ứng: ELECTRONIC = 1, FASHION = 2, HOME = 3.
#
# * In ra tên và giá trị của từng loại.
#
# * Truy cập loại FASHION bằng cách: dùng tên, dùng giá trị (2), dùng tên dạng chuỗi 'FASHION'.
#
# * Duyệt toàn bộ enum và in ra câu: "Loại sản phẩm: <tên>, Mã số: <giá trị>"

# %% [markdown]
# ### Bài 2 – Trạng thái đơn hàng

# %% [markdown]
# Hệ thống đơn hàng có 4 trạng thái: CHỜ_XỬ_LÝ, ĐANG_GIAO, HOÀN_THÀNH, HỦY.
# **Yêu cầu:**
#
# * Tạo enum OrderStatus (gán giá trị số bất kỳ).
#
# * Tạo một đơn hàng với trạng thái ban đầu là CHỜ_XỬ_LÝ.
#
# * In ra màn hình trạng thái hiện tại dưới dạng "Tên trạng thái: ...".
#
# * Kiểm tra xem trạng thái có phải là HOÀN_THÀNH không, in ra True/False.

# %% [markdown]
# ## 🚀 Cấp độ 2 – Trung cấp (So sánh, dùng trong điều kiện, kết hợp list)

# %% [markdown]
# ### Bài 3 – Tính cước phí theo kênh vận chuyển

# %% [markdown]
# Công ty có 3 kênh giao hàng: NORMAL, EXPRESS, SAME_DAY.
# Mỗi kênh có mức phí cơ bản: Normal 2$, Express 5$, SameDay 8$.
# **Yêu cầu:**
#
# * Khai báo enum ShippingMethod có giá trị là các mức phí (number).
#
# * Viết hàm calculate_shipping_cost(method, weight) trong đó:
#
#     * Nếu weight > 10kg thì cộng thêm 3$ (cho tất cả các kênh).
#
#     * Trả về tổng phí.
#
# * Thử với method = ShippingMethod.EXPRESS và weight = 12.
#
# * In ra kết quả.

# %% [markdown]
# ### Bài 4 – Phân loại khách hàng theo điểm thưởng

# %% [markdown]
# Hệ thống loyalty có 3 hạng: BRONZE (0-100 điểm), SILVER (101-300), GOLD (301+).
#
# **Yêu cầu:**
#
# * Khai báo enum Tier với giá trị tương ứng là giới hạn dưới của mỗi hạng.
#
# * Viết hàm get_tier(points) trả về thành viên enum thích hợp.
#
# * Sau đó, cho danh sách điểm của 5 khách hàng: [45, 150, 320, 80, 250], lặp và in ra: "Điểm X -> Hạng Y".

# %% [markdown]
# ### Bài 5 – Thống kê hành vi theo kênh tiếp th

# %% [markdown]
# Công ty chạy chiến dịch qua 3 kênh: EMAIL, SMS, PUSH_NOTIFICATION.
# Log dữ liệu là danh sách các dictionary, mỗi dict có channel (tên kênh dạng string) và user_id.
# Yêu cầu:
#
# * Định nghĩa enum MarketingChannel (các giá trị là string: "email", "sms", "push").
#
# * Viết hàm chuyển đổi string trong log thành enum (xử lý lowercase).
#
# * Đếm số lượng user duy nhất cho mỗi kênh, in ra dictionary với key là enum member, value là số user.
#
# * Tìm kênh có nhiều user nhất (so sánh các enum member để lấy tên).

# %% [markdown]
# ## 🔥 Cấp độ 3 – Nâng cao (Enum với data structures, kết hợp set, dict, xử lý log)

# %% [markdown]
# # BÀI TẬP CHƯƠNG 08

# %% [markdown]
# ## Cấp độ 1 – Cơ bản (Thao tác khởi tạo, thêm/xóa, kiểm tra)

# %% [markdown]
# ### Bài 1 – Danh sách khách hàng VIP

# %% [markdown]
# Công ty có hai danh sách khách hàng đã mua hàng trong tháng 1 và tháng 2. Dữ liệu bị trùng lặp.
# Yêu cầu:
#
# * Tạo một set chứa tất cả khách hàng duy nhất từ danh sách customers_jan và customers_feb.
#
# * Thêm khách hàng mới "Nguyen Van A" vào tập hợp trên.
#
# * Xóa khách hàng "Tran Thi B" nếu có (không báo lỗi nếu không tồn tại).
#
# * Kiểm tra xem "Le Van C" có tồn tại trong tập hợp không.

# %%
customers_jan = ["Mai Dung", "Tran Thi B", "Le Van C", "Mai Dung"]
customers_feb = ["Nguyen Van A", "Le Van C", "Pham Thi D"]

# %% [markdown]
# ### Bài 2 – Khách hàng mới so với cũ

# %% [markdown]
# Công ty có tập existing_customers và danh sách khách hàng đăng ký mới trong tuần (có thể trùng với cũ).
#
# Yêu cầu: In ra danh sách những khách hàng thực sự mới (chưa từng tồn tại trong existing_customers).

# %%
existing_customers = {"C001", "C002", "C003"}
new_registrations = ["C002", "C004", "C005", "C002"]

# %% [markdown]
# Gợi ý: Dùng in hoặc phép hiệu.

# %% [markdown]
# ## 🚀 Cấp độ 2 – Trung cấp (Phép giao, hợp, hiệu, hiệu đối xứng)

# %% [markdown]
# ### Bài 3 – Chiến dịch email marketing

# %% [markdown]
# Bạn có:
#
# * clicked_email: tập khách hàng đã click vào email chiến dịch A.
#
# * opened_email: tập khách hàng đã mở email (nhưng chưa chắc click).
#
# Yêu cầu:
#
# 1. Tìm khách hàng vừa mở vừa click (intersection).
#
# 2. Tìm khách hàng click nhưng không mở (difference).
#
# 4. Tìm khách hàng chỉ mở hoặc chỉ click, không làm cả hai (symmetric difference).
#
# 5. Tổng số khách hàng duy nhất tương tác với email (union).

# %%
clicked_email = {"KH1", "KH2", "KH5"}
opened_email = {"KH2", "KH3", "KH4", "KH5"}

# %% [markdown]
# ### Bài 4 – Mở rộng sản phẩm theo vùng

# %% [markdown]
# Cửa hàng có:
#
# * product_north: sản phẩm bán tại miền Bắc.
#
# * product_south: sản phẩm bán tại miền Nam.
#
# Yêu cầu:
#
# * In ra các sản phẩm chỉ có ở Bắc, không có ở Nam.
#
# * In ra các sản phẩm chỉ có ở Nam, không có ở Bắc.
#
# * Kiểm tra xem có sản phẩm nào bán ở cả hai miền không? Nếu có thì in ra.

# %%
product_north = {"áo", "quần", "mũ", "giày"}
product_south = {"quần", "váy", "giày", "tất"}

# %% [markdown]
# ## 🔥 Cấp độ 3 – Nâng cao (Tập con, rời rạc, frozenset, khử trùng danh sách phức tạp)

# %% [markdown]
# ### Bài 5 – Phân nhóm khách hàng theo sở thích

# %% [markdown]
# Công ty có 3 nhóm sở thích: tech, fashion, sports.
# Một khách hàng có thể thuộc nhiều nhóm.
# **Yêu cầu:**
#
# * Kiểm tra xem tất cả khách hàng trong fashion có phải là tập con của tech không?
#
# * Kiểm tra xem tech và sports có rời rạc (disjoint) không?
#
# * Tạo một frozenset từ tập tech để có thể dùng làm key trong dictionary

# %%
tech = {"KH1", "KH2", "KH5"}
fashion = {"KH2", "KH3"}
sports = {"KH4", "KH6"}

# %% [markdown]
# ### Bài 6 – Khử trùng dữ liệu giao dịch có thứ tự (dùng set + list)

# %% [markdown]
# Bạn nhận được log giao dịch dạng list, mỗi giao dịch là một tuple (user_id, product_id) nhưng có nhiều dòng trùng lặp.
#
# **Yêu cầu:**
#
# * Tạo danh sách các giao dịch duy nhất (giữ nguyên thứ tự xuất hiện đầu tiên).
#
# * Đếm số lượng user_id duy nhất đã giao dịch.
#
# * Đếm số lượng product_id duy nhất được mua

# %%
transactions = [
    ("U1", "P100"), ("U2", "P200"), ("U1", "P100"),
    ("U3", "P100"), ("U2", "P300")
]

# %% [markdown]
# Gợi ý: Dùng set để kiểm tra nhanh, nhưng cần duy trì thứ tự → dùng vòng lặp và set hỗ trợ.

# %% [markdown]
# ### Bài 7 – Tình huống tổng hợp: Phân tích chiến dịch khuyến mãi

# %% [markdown]
# Công ty chạy hai đợt khuyến mãi:
#
# * Đợt 1: promo1_users
#
# * Đợt 2: promo2_users
#
# Bộ phận kinh doanh muốn biết:
#
# 1. Có bao nhiêu khách hàng chỉ tham gia đợt 1?
#
# 2. Có bao nhiêu khách hàng tham gia cả hai đợt?
#
# 3. Nếu muốn gửi email tri ân đến tất cả khách hàng đã tham gia ít nhất một đợt, thì cần gửi đến bao nhiêu người?
#
# 4. Kiểm tra xem có khách hàng nào không tham gia đợt nào trong tập all_customers không?
#
# 5. Trong các khách hàng tham gia đợt 2, có ai chưa từng tham gia đợt 1 và là khách hàng mới (nằm trong new_customers) không? (gợi ý: dùng phép giao giữa hiệu đối xứng hoặc hiệu)

# %%
promo1_users = {"A", "B", "C", "D"}
promo2_users = {"C", "D", "E", "F"}
all_customers = {"A", "B", "C", "D", "E", "F", "G", "H"}
new_customers = {"E", "F", "I"}
